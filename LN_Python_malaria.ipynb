# %% [markdown]
# # Malaria: Wandel der globalen  Verbreitung

# %% [markdown]
# **Gruppe**
# - Darlene Armenio : armdar01@students.zhaw.ch
# - Mimoza Mehmeti : mehmemi@students.zhaw.ch
# - Kipisha Selvan : selvakip@students.zhaw.ch

# %% [markdown]
# **Fragestellung**
# - Wie und warum die globale Vebreitung und Sterblichkeit von Malaria seit dem  20.Jahrhundert sich verändert hat ?
# - Welche Faktoren (Bsp.: Gesundheitsmassnahmen, wirtschaftliche Entwicklung) erklären den Rückgang der Krankheit

# %% [markdown]
# ### 1. Daten beschaffen und laden

# %%
import pandas as pd
from matplotlib import pyplot as plt 

# Dateiname aus Ihrer Frage
file_name = 'global-malaria-deaths-by-world-region.csv'

# Daten mit Pandas laden
try:
    df = pd.read_csv(file_name)
    print("Daten erfolgreich geladen. Die ersten 5 Zeilen:")
    print(df.head()) # Zeigt die ersten 5 Zeilen an
    print("\nSpalteninformationen:")
    print(df.info())
    
except FileNotFoundError:
    print(f"Fehler: Die Datei '{file_name}' wurde nicht gefunden.")
    print("Stellen Sie sicher, dass die Datei im selben Ordner wie das Notebook liegt.")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Daten erfolgreich geladen. Die ersten 5 Zeilen:
#    Entity  Code  Year  malaria_deaths
# 0  Africa   NaN  2000          840000
# 1  Africa   NaN  2001          838000
# 2  Africa   NaN  2002          797000
# 3  Africa   NaN  2003          774000
# 4  Africa   NaN  2004          750000
#
# Spalteninformationen:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Entity          126 non-null    object
#  1   Code            0 non-null      float64
#  2   Year            126 non-null    int64
#  3   malaria_deaths  126 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 4.1+ KB
# None
